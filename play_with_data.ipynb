# %%
import pandas as pd
import numpy as np
import pickle

# %%
df = pd.read_csv('data/test_transaction.csv')

# %%
# Out:
#         TransactionID  TransactionDT  TransactionAmt ProductCD  card1  card2  \
# 502783        4166332       34104978          15.985         C  13832  375.0
# 440462        4104011       32899134          54.500         W   7638  174.0
# 385619        4049168       31519990        4306.950         W  16132  111.0
# 125455        3789004       22709450          52.950         W   1877  310.0
# 496461        4160010       33936635          16.661         C  12184  440.0
# 443608        4107157       32985987         209.950         W   7585  553.0
# 94239         3757788       21579956         157.950         W   5033  269.0
# 173927        3837476       24424313         100.000         H   6955  399.0
# 334068        3997617       29859915          11.804         C   3154  408.0
# 234883        3898432       26588051         213.000         W   6930  555.0
#
#         card3             card4  card5   card6  ...  V330  V331  V332  V333  \
# ...
